# %% [markdown]
# # 2. 축

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' #Windows
matplotlib.rcParams['font.size'] = 15 #글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False #한글 폰트 사용 시. 마이너스 글자가 깨지는 현상 방지

# %%
x = [1, 2, 3]
y = [2, 4, 8]

# %%
plt.plot(x, y)
plt.title('꺾은선 그래프', fontdict={'family':'Malgun Gothic', 'size':20}) #개별 폰트 설정
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')

# %%
plt.plot(x, y)
plt.xlabel('X축')
plt.ylabel('y축')
# Out:
# Text(0, 0.5, 'y축')

# %%
plt.plot(x, y)
plt.xlabel('X축', color='red')
plt.ylabel('y축', color='#00aa00')
# Out:
# Text(0, 0.5, 'y축')

# %%
plt.plot(x, y)
plt.xlabel('X축', color='red', loc='right') #x축 loc : left, center, right
plt.ylabel('y축', color='#00aa00', loc='top') #y축 loc : top, center, bottom
# Out:
# Text(0, 1, 'y축')

# %%
plt.plot(x, y)
plt.xticks([1, 2, 3])
plt.yticks([3, 6, 9, 12])
plt.show()
