# %% [markdown]
# # 1. 인구 피라미드

# %% [markdown]
# ## 남자 데이터 정의

# %%
import pandas as pd
file_name = '202408_202408_연령별인구현황_월간.xlsx'
df_m = pd.read_excel(file_name, skiprows=3, index_col='행정기관', usecols='B, E:Y')
df_m.head(3)
# Out:
# C:\Users\bobae\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#             0~4세     5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국       657,672  980,329  1,195,532  1,184,636  1,402,427  1,743,714
# 서울특별시    105,003  147,317    181,411    189,697    253,368    373,457
# 부산광역시     37,075   57,997     69,329     65,425     85,275    101,501
#
#             30~34세     35~39세     40~44세     45~49세  ...     55~59세  \
# 행정기관                                                 ...
# 전국       1,821,544  1,622,063  2,013,109  1,943,242  ...  2,141,661
# 서울특별시      397,099    321,478    357,433    331,903  ...    347,836
# 부산광역시      106,507     94,620    123,327    116,877  ...    129,556
#
#             60~64세     65~69세     70~74세   75~79세   80~84세   85~89세  90~94세  \
# 행정기관
# 전국       2,096,115  1,724,857  1,101,643  787,398  527,736  243,677  63,555
# 서울특별시      335,339    291,351    196,229  147,477   99,469   43,051  10,847
# 부산광역시      136,952    126,958     87,867   61,352   39,647   16,019   3,672
#
#          95~99세 100세 이상
# 행정기관
# 전국       10,688   1,582
# 서울특별시     2,102     351
# 부산광역시       550      70
#
# [3 rows x 21 columns]

# %%
df_m.iloc[0] = df_m.iloc[0].str.replace(',', '').astype(int) #쉼표(,) 제거 후 int형으로 전환

# %%
df_m.iloc[0]
# Out:
# 0~4세        657672
# 5~9세        980329
# 10~14세     1195532
# 15~19세     1184636
# 20~24세     1402427
# 25~29세     1743714
# 30~34세     1821544
# 35~39세     1622063
# 40~44세     2013109
# 45~49세     1943242
# 50~54세     2259628
# 55~59세     2141661
# 60~64세     2096115
# 65~69세     1724857
# 70~74세     1101643
# 75~79세      787398
# 80~84세      527736
# 85~89세      243677
# 90~94세       63555
# 95~99세       10688
# 100세 이상       1582
# Name: 전국  , dtype: object

# %% [markdown]
# ## 여자 데이터 정의

# %%
df_w = pd.read_excel(file_name, skiprows=3, index_col='행정기관', usecols='B, AB:AV')
df_w.head(3)
# Out:
# C:\Users\bobae\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#           0~4세.1   5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1  \
# 행정기관
# 전국       626,995  932,105  1,133,396  1,116,047  1,298,168  1,591,913
# 서울특별시     99,687  140,246    171,739    183,117    289,257    412,413
# 부산광역시     34,995   55,536     65,626     62,590     81,571     96,286
#
#           30~34세.1   35~39세.1   40~44세.1   45~49세.1  ...   55~59세.1  \
# 행정기관                                                 ...
# 전국       1,639,684  1,520,907  1,938,266  1,887,373  ...  2,125,336
# 서울특별시      394,896    322,988    362,642    342,449  ...    362,963
# 부산광역시       98,530     90,148    120,263    114,885  ...    138,687
#
#           60~64세.1   65~69세.1   70~74세.1 75~79세.1 80~84세.1 85~89세.1 90~94세.1  \
# 행정기관
# 전국       2,117,467  1,819,625  1,242,430  972,105  814,530  506,059  198,271
# 서울특별시      364,119    333,005    232,329  184,660  134,471   74,291   27,881
# 부산광역시      152,906    144,690    103,869   77,706   58,921   32,050   11,286
#
#         95~99세.1 100세 이상.1
# 행정기관
# 전국        47,129     7,155
# 서울특별시      7,189     1,171
# 부산광역시      2,829       372
#
# [3 rows x 21 columns]

# %%
df_m.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.columns
# Out:
# Index(['0~4세.1', '5~9세.1', '10~14세.1', '15~19세.1', '20~24세.1', '25~29세.1',
#        '30~34세.1', '35~39세.1', '40~44세.1', '45~49세.1', '50~54세.1', '55~59세.1',
#        '60~64세.1', '65~69세.1', '70~74세.1', '75~79세.1', '80~84세.1', '85~89세.1',
#        '90~94세.1', '95~99세.1', '100세 이상.1'],
#       dtype='object')

# %%
df_w.columns = df_m.columns #컬럼명 통일
df_w.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.iloc[0] = df_w.iloc[0].str.replace(',', '').astype(int) #쉼표(,) 제거 후 int형으로 전환
df_w
# Out:
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국          626995   932105  1133396  1116047  1298168  1591913  1639684
# 서울특별시       99,687  140,246  171,739  183,117  289,257  412,413  394,896
# 부산광역시       34,995   55,536   65,626   62,590   81,571   96,286   98,530
# 대구광역시       26,951   43,410   52,131   51,022   60,677   68,532   68,694
# 인천광역시       39,650   56,681   67,181   65,273   75,236   96,447  105,121
# 광주광역시       18,150   28,230   35,229   35,477   41,547   46,957   43,695
# 대전광역시       18,623   26,500   32,515   33,553   43,351   50,077   47,443
# 울산광역시       14,137   22,386   27,180   25,125   22,635   28,154   31,101
# 세종특별자치시      8,147   12,507   13,873   11,799    8,404    9,851   14,112
# 경기도        190,544  275,175  327,912  317,721  351,561  430,126  462,582
# 강원특별자치도     18,060   24,764   30,335   30,955   33,690   35,952   37,298
# 충청북도        19,546   28,721   35,356   34,115   36,300   42,442   42,943
# 충청남도        26,611   40,666   49,601   47,931   47,700   50,815   55,992
# 전북특별자치도     18,422   29,254   38,675   39,381   41,244   42,854   41,585
# 전라남도        20,637   29,893   38,524   37,566   36,108   39,285   39,851
# 경상북도        27,419   42,507   52,202   50,865   49,317   52,747   57,248
# 경상남도        36,231   60,969   77,626   73,432   64,220   71,205   79,320
# 제주특별자치도      9,185   14,660   17,691   16,125   15,350   17,770   19,273
#
#             35~39세   40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  \
# 행정기관                                  ...
# 전국         1520907  1938266  1887373  ...  2125336  2117467  1819625  1242430
# 서울특별시      322,988  362,642  342,449  ...  362,963  364,119  333,005  232,329
# 부산광역시       90,148  120,263  114,885  ...  138,687  152,906  144,690  103,869
# 대구광역시       62,687   87,049   88,405  ...  106,949  105,860   88,421   64,316
# 인천광역시       95,565  119,375  112,529  ...  129,333  127,766  102,133   62,348
# 광주광역시       40,040   55,202   56,247  ...   58,656   54,016   44,252   30,903
# 대전광역시       41,604   53,264   54,373  ...   59,479   57,053   48,285   31,978
# 울산광역시       30,824   43,069   41,485  ...   51,454   47,746   38,134   23,655
# 세종특별자치시     15,880   20,953   18,152  ...   11,677   10,492    8,672    5,323
# 경기도        442,647  556,849  533,767  ...  563,234  524,350  419,994  265,458
# 강원특별자치도     36,207   48,830   50,835  ...   64,836   72,856   65,946   43,138
# 충청북도        41,965   54,513   54,409  ...   68,593   68,409   60,475   40,084
# 충청남도        58,328   76,165   73,822  ...   82,711   86,890   75,606   54,367
# 전북특별자치도     40,763   56,050   60,041  ...   72,810   75,952   67,535   51,486
# 전라남도        39,626   54,391   56,292  ...   73,411   79,613   70,755   54,258
# 경상북도        59,273   82,733   84,037  ...  110,252  119,093  105,839   79,822
# 경상남도        83,354  120,154  120,099  ...  142,852  144,113  124,168   84,907
# 제주특별자치도     19,008   26,764   25,546  ...   27,439   26,233   21,715   14,189
#
#             75~79세   80~84세   85~89세  90~94세  95~99세 100세 이상
# 행정기관
# 전국          972105   814530   506059  198271   47129    7155
# 서울특별시      184,660  134,471   74,291  27,881   7,189   1,171
# 부산광역시       77,706   58,921   32,050  11,286   2,829     372
# 대구광역시       47,958   40,277   23,247   8,425   1,810     222
# 인천광역시       48,500   37,994   23,817   9,859   2,509     404
# 광주광역시       25,697   19,434   11,341   4,606   1,030     169
# 대전광역시       23,824   19,309   11,837   4,591   1,089     184
# 울산광역시       15,264   11,701    6,615   2,536     601      76
# 세종특별자치시      3,728    3,171    2,172   1,011     258      37
# 경기도        208,308  167,213  103,703  40,833  10,219   1,532
# 강원특별자치도     35,185   33,526   21,023   8,152   2,210     321
# 충청북도        30,308   29,361   19,620   7,688   1,669     233
# 충청남도        42,775   41,298   30,268  12,408   2,737     419
# 전북특별자치도     43,667   40,524   27,603  11,414   2,622     418
# 전라남도        49,106   49,243   33,484  13,459   2,817     490
# 경상북도        58,934   59,828   40,142  15,438   3,497     508
# 경상남도        64,271   57,975   37,688  15,171   3,269     367
# 제주특별자치도     12,214   10,284    7,158   3,513     774     232
#
# [18 rows x 21 columns]

# %% [markdown]
# ## 데이터 시각화

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' #Windows
matplotlib.rcParams['font.size'] = 15 #글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False #한글 폰트 사용 시. 마이너스 글자가 깨지는 현상 방지

# %%
plt.figure(figsize=(10, 7))
plt.barh(df_m.columns, -df_m.iloc[0] // 1000) #단위 : 천 명
plt.barh(df_w.columns, df_w.iloc[0] // 1000)
plt.title('2024년 대한민국 인구 피라미드')
plt.savefig('2024_인구피라미드.png', dpi=100)
plt.show()
